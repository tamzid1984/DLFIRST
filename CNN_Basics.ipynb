# %% [markdown]
# <a href="https://colab.research.google.com/github/tamzid1984/DLFIRST/blob/main/CNN_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense, Activation, Flatten, Conv2D, MaxPool2D, MaxPooling2D, AveragePooling2D, GlobalAveragePooling2D, ZeroPadding2D, Input
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10, mnist
from tensorflow.keras.preprocessing import image

# %%
(x_train, y_train), _ = cifar10.load_data()
# Out:
# ...
# 170498071/170498071 [==============================] - 2s 0us/step

# %%
print(x_train[0].shape)
print(y_train[0].shape)
# Out:
# (32, 32, 3)
# (1,)

# %%
fig = plt.figure(figsize=(10, 10))
for i in range(9):
    fig.add_subplot(3, 3, i+1)
    plt.imshow(x_train[i])
    plt.show()

# %%
(x_train, y_train), _ = mnist.load_data()
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
print(x_train[0].shape)
print(y_train[0].shape)
# Out:
# (28, 28)
# ()

# %%
fig = plt.figure(figsize=(10, 10))
for i in range(9):
    fig.add_subplot(3, 3, i+1)
    plt.imshow(x_train[i])
    plt.show()

# %% [markdown]
# ### Padding
#  * Valid Padding --> No padding needded
#  * Same Paddding --> kernel size = 4, padding 4/2 ---> kernelsize/2

# %%
model = Sequential()
model.add(Conv2D(input_shape = (10, 10, 3),
                filters = 10, kernel_size = (3, 3),
                strides = (1, 1), padding = "valid"))

# %%
print(model.output_shape)
# Out:
# (None, 8, 8, 10)

# %%
model = Sequential()
model.add(Conv2D(input_shape = (10, 10, 3),
                filters = 10, kernel_size = (6, 6),
                strides = (1, 1), padding = "same"))

# %%
print(model.output_shape)
# Out:
# (None, 10, 10, 10)

# %%
model = Sequential()
model.add(Conv2D(input_shape= (10, 10, 3),
                filters = 10,kernel_size =(3, 3),
                strides = (1, 1), padding = 'same'))

# %%
print(model.output_shape)
# Out:
# (None, 10, 10, 10)

# %%
model = Sequential()
model.add(Conv2D(input_shape= (10, 10, 3),
                filters = 20,kernel_size =(3, 3),
                strides = (1, 1), padding = 'same'))

# %%
print(model.output_shape)
# Out:
# (None, 10, 10, 20)

# %%
model.add(MaxPooling2D(pool_size = (2, 2), padding = "same"))

# %%
print(model.output_shape)
# Out:
# (None, 5, 5, 20)
